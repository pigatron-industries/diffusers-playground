# %%
# !pip install -r ../../requirements.txt

# %%
import path
path.setPathLocalNotebook()

from diffuserslib import DiffusersView, DiffusersPipelines, startWebServer, DiffusersBaseModel, AUTOENCODER_MODEL_1_5

local_weight_dir = '~/stable-diffusion/weights'
learned_embeds_path = "~/stable-diffusion/embeds"

pipelines = DiffusersPipelines(localmodelpath=local_weight_dir, device = "mps", safety_checker=False, cache_dir=None)
pipelines.loadPresetFile("../../modelconfig.yml")
pipelines.loadTextEmbeddings(learned_embeds_path)

DiffusersView.pipelines = pipelines

startWebServer()
# Out:
# 127.0.0.1 - - [23/Nov/2023 17:53:14] "POST /api/async/generateTiled HTTP/1.1" 200 -
# === generateTiled ===
# Processing 3 x 1 slices
#   0%|          | 0/10 [00:00<?, ?it/s]
# 127.0.0.1 - - [23/Nov/2023 17:53:19] "GET /api/async HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2023 17:53:24] "GET /api/async HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2023 17:53:29] "GET /api/async HTTP/1.1" 200 -
# <PIL.Image.Image image mode=RGB size=512x512>
#   0%|          | 0/10 [00:00<?, ?it/s]
# 127.0.0.1 - - [23/Nov/2023 17:53:34] "GET /api/async HTTP/1.1" 200 -
# <PIL.Image.Image image mode=RGB size=512x512>
# 127.0.0.1 - - [23/Nov/2023 17:53:39] "GET /api/async HTTP/1.1" 200 -
#   0%|          | 0/10 [00:00<?, ?it/s]
# 127.0.0.1 - - [23/Nov/2023 17:53:44] "GET /api/async HTTP/1.1" 200 -
# <PIL.Image.Image image mode=RGB size=512x512>
# 127.0.0.1 - - [23/Nov/2023 17:53:49] "GET /api/async HTTP/1.1" 200 -
