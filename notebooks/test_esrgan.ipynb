# %%
# !pip install -r ../requirements.txt

# %%
import path, os
from PIL import Image
from IPython.display import display
path.setPathLocalNotebook()

from diffuserslib import upscaleESRGAN

inimage = Image.open("test.png")
outimage = upscaleESRGAN(inimage, 4, "remacri")
display(outimage)
# Out:
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /Users/rob/workspace/projects/diffusers-playground/workspace/src/esrgan/upsc │
# │ ale.py:567 in main                                                           │
# │                                                                              │
# │   564 │   │   alpha_boundary_offset=alpha_boundary_offset,                   │
# │   565 │   │   alpha_mode=alpha_mode,                                         │
# │   566 │   )                                                                  │
# │ ❱ 567 │   upscale.run()                                                      │
# │   568                                                                        │
# │   569                                                                        │
# │   570 if __name__ == "__main__":                                             │
# │                                                                              │
# │ ╭───────────────────────────── locals ─────────────────────────────╮         │
# │ │ alpha_boundary_offset = 0.2                                      │         │
# │ │            alpha_mode = None                                     │         │
# │ │       alpha_threshold = 0.5                                      │         │
# │ │          binary_alpha = False                                    │         │
# │ │ cache_max_split_depth = False                                    │         │
# │ │                   cpu = False                                    │         │
# │ │          delete_input = False                                    │         │
# │ │             device_id = 0                                        │         │
# │ │                  fp16 = False                                    │         │
# │ │                 input = PosixPath('input')                       │         │
# │ │                 model = '4x_remacri.pth'                         │         │
# │ │                output = PosixPath('output')                      │         │
# │ │               reverse = False                                    │         │
# │ │              seamless = None                                     │         │
# │ │         skip_existing = False                                    │         │
# │ │         ternary_alpha = False                                    │         │
# │ │               upscale = <__main__.Upscale object at 0x11fb089d0> │         │
# │ │               verbose = False                                    │         │
# │ ╰──────────────────────
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /var/folders/5w/xlkmsvyj2tscz43jpx6j7qt00000gn/T/ipykernel_81801/696122805.py:9 in <cell line:   │
# │ 9>                                                                                               │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ '/var/folders/5w/xlkmsvyj2tscz43jpx6j7qt00000gn/T/ipykernel_81801/696122805.py'                  │
# │                                                                                                  │
# │ /Users/rob/workspace/projects/diffusers-playground/workspace/../diffuserslib/ImageTools.py:20 in │
# │ upscaleESRGAN                                                                                    │
# │                                                                                                  │
# │   17 │   outfile = "output/work.png"                                                             │
# │   18 │   model = f'4x_{model}.pth'                                                               │
# │   19 │   inimage.save(infile)                                                                    │
# │ ❱ 20 │   runcmd(['python', 'upscale.py', model])                                                 │
# │   21 │   return Image.open(outfile)                                                              │
# │   22                                                                                             │
# │                                                                                                  │
# │ /Users/rob/workspace/projects/diffusers-playground/workspace/../diffuserslib/ImageTools.py:11 in │
# │ runcmd                                                                                           │
# │                                                                                                  │
# │    8                                                                                             │
# │    9                                                                                             │
# │   10 def runcmd(cmd, shell=False):                                                               │
# │ ❱ 11 │   print(subprocess.run(cmd, stdout=subprocess.PIPE, shell=shell).stdout.decode('utf-8'    │
# │   12                                                                                             │
# │   13                                                                                             │
# │   14 def upscaleESRGAN(inimage, scale=4, model="remacri"):                                       │
# │                                                                                                  │
# │ /usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/sub │
# │ process.py:507 in run                                                                            │
# │                                                                                                  │
# │    504 │                                                                                         │
# │    505 │   with Popen(*popenargs, **kwargs) as process:                                          │
# │    506 │   │   try:                                                                              │
# │ ❱  507 │   │   │   stdout, stderr = process.communicate(input, timeout=timeout)                  │
# │    508 │   │   except TimeoutExpired as exc:                                                     │
# │    509 │   │   │   process.kill()                                                                │
# │    510 │   │   │   if _mswindows:                                                                │
# │                                                                                                  │
# │ /usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/sub │
# │ process.py:1121 in communicate                                                                   │
# │                                                                                                  │
# │   1118 │   │   │   if self.stdin:                                                                │
# │   1119 │   │   │   │   self._stdin_write(input)                                                  │
# │   1120 │   │   │   elif self.stdout:                                                             │
# │ ❱ 1121 │   │   │   │   stdout = self.stdout.read()                                               │
# │   1122 │   │   │   │   self.stdout.close()                                                       │
# │   1123 │   │   │   elif self.stderr:                                                             │
# │   1124 │   │   │   │   stderr = self.stderr.read()                                               │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
